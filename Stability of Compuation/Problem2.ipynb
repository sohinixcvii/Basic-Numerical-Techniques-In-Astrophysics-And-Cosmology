# %% [markdown]
# # Problem 2.2
# ![image.png](attachment:c1019b78-2ca4-47ee-aff8-bc979430d629.png)

# %%
import numpy as np

x=[0.1,0.01,0.001]
for v in x:
    y=(v**2+1.0)**0.5 - 1.0
    print("Value using method 1 for x= "+str(v)+" is: "+str(y))
    y=v**2/(((v**2+1.0)**0.5)+1.0)
    print("Value using method 2 for x= "+str(v)+" is: "+str(y))
# Out:
# Value using method 1 for x= 0.1 is: 0.00498756211208895
# Value using method 2 for x= 0.1 is: 0.004987562112089027
# Value using method 1 for x= 0.01 is: 4.9998750062396624e-05
# Value using method 2 for x= 0.01 is: 4.99987500624961e-05
# Value using method 1 for x= 0.001 is: 4.999998750587764e-07
# Value using method 2 for x= 0.001 is: 4.999998750000624e-07
