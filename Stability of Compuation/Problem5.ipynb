# %% [markdown]
# # Problem 2.5
# ![image.png](attachment:bd7c881d-3031-449e-aeea-2c7b403baf29.png)

# %%
import numpy as np
import matplotlib as plt

x=[2.718281823,-3.141592654,1.414213562,0.5772156649,0.3010299957]
y =[1486.2497,878366.9879,-22.37492,4773714.647,0.000185049]

# %%
d=np.dot(x,y)
print("Dot product is: "+str(d))
# Out:
# Dot product is: -7.4313015829829965e-06

# %%
i=1
s=0
while i<=5:
    s=s+(x[i-1]*y[i-1])
    i+=1
print("The forward order sum is: "+str(s))
# Out:
# The forward order sum is: -7.431385965330528e-06

# %%
i=5
s=0
while i>=1:
    s=s+(x[i-1]*y[i-1])
    i-=1
print("The reverse order sum is: "+str(s))
# Out:
# The reverse order sum is: -7.431405265378999e-06

# %%
d=[]
i=1
while i<=5:
    res=x[i-1]*y[i-1]
    d.append(res)
    i+=1
d.sort()
s=0
for l in d:
    s=s+l
print("largest to smallest order (add positive numbers in order from largest to smallest, then add negative numbers in order from smallest to largest and then add the two partial sums): "+str(s))
# Out:
# largest to smallest order (add positive numbers in order from largest to smallest, then add negative numbers in order from smallest to largest and then add the two partial sums): -7.431488484144211e-06

# %%
d=[]
i=1
while i<=5:
    res=x[i-1]*y[i-1]
    d.append(res)
    i+=1
d.sort(reverse=True)
s=0
for l in d:
    s=s+l
print("smallest to largest order (reverse order of adding in the previous methods): "+str(s))
# Out:
# smallest to largest order (reverse order of adding in the previous methods): -7.431488484144211e-06
